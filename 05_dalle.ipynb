# %% [markdown]
# <a href="https://colab.research.google.com/github/hata-junnosuke/python_openai_colab/blob/main/05_dalle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai==1.7.2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.1/212.1 kB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.0 MB/s eta 0:00:00
# ...

# %%
from openai import OpenAI
from google.colab import userdata
import urllib.request
from PIL import Image
import cv2
from google.colab.patches import cv2_imshow

client = OpenAI(
    api_key = userdata.get("OPENAPI_API_KEY")
)

# %%
response = client.images.generate(
    model = "dall-e-2",
    prompt = "sleeping cat",
    size="256x256",
    n=1
)

image_url = response.data[0].url
urllib.request.urlretrieve(image_url, "image.png")
img = cv2.imread("image.png")
cv2_imshow(img)

print(response.data[0].url)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-rpyoFkPEdsmCU3DE9ryVxPaP/user-MEF9vFx4yBUdWMbgAmMWOHVA/img-VNX86plCXEzQPhPFpdm3lANH.png?st=2024-04-05T02%3A46%3A36Z&se=2024-04-05T04%3A46%3A36Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2024-04-04T23%3A40%3A19Z&ske=2024-04-05T23%3A40%3A19Z&sks=b&skv=2021-08-06&sig=miQqCch8RN902cFyVjuOzcWCZ0yTCa8zrJhscSFWxgE%3D
